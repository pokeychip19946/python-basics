# %% [markdown]
# <a href="https://colab.research.google.com/github/pokeychip19946/python-basics/blob/master/_SWMA_lab_2_Divyam_Verma_R103218043_CSE_BAO_B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("salries.csv")
df
# Out:
#           Id  ...   TotalPay
# 0          1  ...  567595.43
# 1          2  ...  538909.28
# 2          3  ...  335279.91
# 3          4  ...  332343.61
# 4          5  ...  326373.19
# ...      ...  ...        ...
# 17834  17835  ...   68869.02
# 17835  17836  ...   68869.02
# 17836  17837  ...   68860.48
# 17837  17838  ...   68858.52
# 17838  17839  ...   68858.07
#
# [17839 rows x 4 columns]

# %%
grouped = df.groupby('JobTitle')
for name,group in grouped:
   print(name)
   print(group)
# Out:
# Streaming output truncated to the last 5000 lines.
# 15650  15651       NINA POGOSYAN  LIBRARIAN I  75411.69
# 15660  15661        BRIAN WEAVER  LIBRARIAN I  75381.53
# 15675  15676            JANE BAO  LIBRARIAN I  75306.91
# ...      ...                 ...          ...       ...
# 17446  17447  STEPHEN MCLAUGHLIN  LIBRARIAN I  70011.15
# 17576  17577         DORCAS WONG  LIBRARIAN I  69623.10
# 17636  17637       WAI-LING TONG  LIBRARIAN I  69454.86
# 17683  17684     ROSALIND MERLIN  LIBRARIAN I  69231.98
# 17758  17759   CHARLOTTE SANDERS  LIBRARIAN I  69029.31
#
# [72 rows x 4 columns]
# LIBRARIAN II
#           Id            EmployeeName      JobTitle  TotalPay
# 12877  12878           TERRY CARLSON  LIBRARIAN II  85342.45
# 13145  13146         SHELLIE COCKING  LIBRARIAN II  84321.47
# 13454  13455              LORNA CHEE  LIBRARIAN II  83413.52
# 13523  13524               JAY SMITH  LIBRARIAN II  83123.26
# 13546  13547        SHELLEY SORENSON  LIBRARIAN II  83044.64
# ...

# %%
import numpy as np

# %%
grouped = df.groupby('JobTitle')
df = grouped['TotalPay'].agg( np.mean)
print(df)
# Out:
# JobTitle
# ADMINISTRATIVE ANALYST                     73954.969661
# ADMINISTRATIVE ANALYST II                  75585.820000
# ADMINISTRATIVE ANALYST III                 92698.515000
# ADMINISTRATIVE ENGINEER                   127961.430000
# ADMINISTRATIVE SERVICES MANAGER            88392.685000
#                                               ...
# WIRE ROPE CABLE MAINTENANCE MECHANIC      145073.492500
# WIRE ROPE CABLE MAINTENANCE SUPERVISOR    199628.970000
# WORKER'S COMPENSATION ADJUSTER             75332.068889
# WORKER'S COMPENSATION SUPERVISOR I         91020.726000
# X-RAY LABORATORY AIDE                      78466.305000
# Name: TotalPay, Length: 808, dtype: float64

# %%
import matplotlib.pyplot as plt
df.plot.line()
